# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://realpython.com/python-web-scraping-practical-introduction/"

# %%
page = requests.get(url)

# %%
html = page.text

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
paragraphs = soup.find_all('p')[9]

# %%
content = ' '.join([p.get_text() for p in paragraphs])

# %%
content
# Out:
# 'Note:  This tutorial is adapted from the chapter “Interacting With the Web” in  Python Basics: A Practical Introduction to Python 3 .'

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(content)

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Note VERB ROOT
# : PUNCT punct
#   SPACE dep
# This DET det
# tutorial NOUN nsubjpass
# is AUX auxpass
# adapted VERB ccomp
# from ADP prep
# the DET det
# chapter NOUN pobj
# “ PUNCT punct
# Interacting VERB acl
# With ADP prep
# the DET det
# Web NOUN pobj
# ” PUNCT punct
# in ADP prep
#   SPACE dep
# Python PROPN compound
# Basics NOUN pobj
# : PUNCT punct
# A DET det
# Practical ADJ amod
# Introduction NOUN appos
# to ADP prep
# Python PROPN pobj
# 3 NUM nummod
# . PUNCT punct

# %%
for token in doc:
    print(token.text)
# Out:
# Note
# :
#
# This
# tutorial
# is
# adapted
# from
# the
# chapter
# “
# Interacting
# With
# the
# Web
# ”
# in
#
# Python
# Basics
# :
# A
# Practical
# Introduction
# to
# Python
# 3
# .

# %%
for t in doc:
    print(t.text,"\t", t.lemma_)
# Out:
# Note 	 note
# : 	 :
#
# This 	 this
# tutorial 	 tutorial
# is 	 be
# adapted 	 adapt
# from 	 from
# the 	 the
# chapter 	 chapter
# “ 	 "
# Interacting 	 interact
# With 	 with
# the 	 the
# Web 	 web
# ” 	 "
# in 	 in
#
# Python 	 Python
# Basics 	 basic
# : 	 :
# A 	 a
# Practical 	 practical
# Introduction 	 introduction
# to 	 to
# Python 	 Python
# 3 	 3
# . 	 .

# %%
for t in doc:
    if not t.is_stop:
        print(t)
# Out:
# Note
# :
#
# tutorial
# adapted
# chapter
# “
# Interacting
# Web
# ”
#
# Python
# Basics
# :
# Practical
# Introduction
# Python
# 3
# .

# %%
from spacy import displacy

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7e42a90feb4a4e048c347c008d67d9a0-0" class="displacy" width="2580" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Note:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">tutorial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">adapted</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">chapter “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">Interacting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">With</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Web”</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">Python</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">Basics:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">Practical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">Introduction</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">Python</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">3 .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e42a90feb4a4e048c347c008d67d9a0-0-0" stroke-width="2px" d="M70,222.0 C70,167.0 145.0,167.0 145.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e42a90feb4a4e048c347c008d67d9a0-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M145.0,224.0 L153.0,212.0 137.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e42a90feb4a4e048c347c008d67d9a0-0-1" stroke-width="2px" d="M290,222.0 C290,167.0 365.0,167.0 365.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e42a90feb4a4e048c347c008d67d9a0-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,224.0 L282,212.0 298,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e42a90feb4a4e048c347c008d67d9a0-0-2" stroke-width="2px" d="M400,222.0 C400,112.0 590.0,112.0 590.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7e42a90feb4a4e048c347c008d67d9a0-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,224.0 L392,212.0 408,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7e42a90feb4a4e048c347c008d67d9a0-0-3" stroke-width="2px" d="M510,222.0 C510,167.0 585.0,167.0 585.0,222.0" fill="none" stroke="currentColor"/>
#     <te

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Note:  This tutorial is adapted from the chapter “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Interacting With the Web
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ” in
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python Basics: A Practical Introduction to Python 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  .</div></span>

# %%
url = "https://en.wikipedia.org/wiki/Web_scraping"

# %%
page = requests.get(url)
html = page.text
soup = BeautifulSoup(html, 'html.parser')

# %%
para = soup.find_all('p')[0]

# %%
content = ' '.join([p.get_text() for p in para])

# %%
content
# Out:
# 'Web scraping ,  web harvesting , or  web data extraction  is  data scraping  used for  extracting data  from  websites . [1]  Web scraping software may directly access the  World Wide Web  using the  Hypertext Transfer Protocol  or a web browser. While web scraping can be done manually by a software user, the term typically refers to automated processes implemented using a  bot  or  web crawler . It is a form of copying in which specific data is gathered and copied from the web, typically into a central local  database  or spreadsheet, for later  retrieval  or  analysis .\n'

# %%
doc2 = nlp(content)

# %%
for t in doc2:
    print(t.text, t.pos_, t.dep_)
# Out:
# Web NOUN compound
# scraping NOUN nsubj
# , PUNCT punct
#   SPACE dep
# web NOUN compound
# harvesting NOUN conj
# , PUNCT punct
# or CCONJ cc
#   SPACE dep
# web NOUN compound
# data NOUN compound
# extraction NOUN conj
#   SPACE dep
# is AUX ROOT
#   SPACE dep
# data NOUN attr
# scraping VERB acl
#   SPACE dep
# used VERB xcomp
# for ADP prep
#   SPACE dep
# extracting VERB pcomp
# data NOUN dobj
#   SPACE dep
# from ADP prep
#   SPACE dep
# websites NOUN pobj
# . PUNCT punct
# [ X dep
# 1 X nmod
# ] PUNCT nmod
#   SPACE dep
# Web NOUN compound
# scraping NOUN amod
# software NOUN nsubj
# may AUX aux
# directly ADV advmod
# access VERB ROOT
# the DET det
#   SPACE dep
# World PROPN compound
# Wide ADJ amod
# Web NOUN dobj
#   SPACE dep
# using VERB acl
# the DET det
#   SPACE dep
# Hypertext PROPN compound
# Transfer PROPN compound
# Protocol PROPN dobj
#   SPACE dep
# or CCONJ cc
# a DET det
# web NOUN compound
# browser NOUN conj
# . PUNCT punct
# While SCONJ mark
# web NOUN compound
# scraping NOUN nsubjpass
# can AUX aux
# be AUX auxpass
# done VERB advcl
# manually ADV advmod
# by ADP agent
# a DET det
# software NOUN compound
# user NOUN pobj
# , PUNCT punct
# the DET det
# term NOUN nsubj
# typically ADV advmod
# refers VERB ROOT
# to ADP prep
# automated VERB amod
# processes NOUN pobj
# implemented VERB acl
# using VERB xcomp
# a DET det
#   SPACE dep
# bot NOUN dobj
#   SPACE dep
# or CCONJ cc
#   SPACE dep
# web NOUN compound
# crawler NOUN conj
# . PUNCT punct
# It PRON nsubj
# is AUX ROOT
# a DET det
# form NOUN attr
# of ADP prep
# copying NOUN pobj
# in ADP prep
# which PRON pobj
# specific ADJ amod
# data NOUN nsubjpass
# is AUX auxpass
# gathered VERB relcl
# and CCONJ cc
# copied VERB conj
# from ADP prep
# the DET det
# web NOUN pobj
# , PUNCT punct
# typically ADV advmod
# into ADP prep
# a DET det
# central ADJ amod
# local ADJ amod
#   SPACE dep
# database NOUN pobj
#   SPACE dep
# or CCONJ cc
# spreadsheet VERB conj
# , PUNCT punct
# for ADP prep
# later ADV amod
#   SPACE dep
# retrieval NOUN pobj
#   SPACE dep
# or CCONJ cc
#   SPACE dep
# analysis NOUN conj
# . PUNCT punct
#
#  SPACE dep

# %%
for t in doc2:
    print(t.text,"\t", t.lemma_)
# Out:
# Web 	 web
# scraping 	 scraping
# , 	 ,
#
# web 	 web
# harvesting 	 harvesting
# , 	 ,
# or 	 or
#
# web 	 web
# data 	 datum
# extraction 	 extraction
#
# is 	 be
#
# data 	 datum
# scraping 	 scrape
#
# used 	 use
# for 	 for
#
# extracting 	 extract
# data 	 datum
#
# from 	 from
#
# websites 	 website
# . 	 .
# [ 	 [
# 1 	 1
# ] 	 ]
#
# Web 	 web
# scraping 	 scraping
# software 	 software
# may 	 may
# directly 	 directly
# access 	 access
# the 	 the
#
# World 	 World
# Wide 	 wide
# Web 	 web
#
# using 	 use
# the 	 the
#
# Hypertext 	 Hypertext
# Transfer 	 Transfer
# Protocol 	 Protocol
#
# or 	 or
# a 	 a
# web 	 web
# browser 	 browser
# . 	 .
# While 	 while
# web 	 web
# scraping 	 scraping
# can 	 can
# be 	 be
# done 	 do
# manually 	 manually
# by 	 by
# a 	 a
# software 	 software
# user 	 user
# , 	 ,
# the 	 the
# term 	 term
# typically 	 typically
# refers 	 refer
# to 	 to
# automated 	 automate
# processes 	 process
# implemented 	 implement
# using 	 use
# a 	 a
#
# bot 	 bot
#
# or 	 or
#
# web 	 web
# crawler 	 crawler
# . 	 .
# It 	 it
# is 	 be
# a 	 a
# form 	 form
# of 	 of
# copying 	 copying
# in 	 in
# which 	 which
# specific 	 specific
# data 	 data
# is 	 be
# gathered 	 gather
# and 	 and
# copied 	 copy
# from 	 from
# the 	 the
# web 	 web
# , 	 ,
# typically 	 typically
# into 	 into
# a 	 a
# central 	 central
# local 	 local
#
# database 	 database
#
# or 	 or
# spreadsheet 	 spreadsheet
# , 	 ,
# for 	 for
# later 	 later
#
# retrieval 	 retrieval
#
# or 	 or
#
# analysis 	 analysis
# . 	 .

# %%
new = ''
for t in doc2:
    if not t.is_stop:
        new += t.text
print(new)
# Out:
# Webscraping, webharvesting, webdataextraction  datascraping  extractingdata  websites.[1] Webscrapingsoftwaredirectlyaccess WorldWideWeb  HypertextTransferProtocol webbrowser.webscrapingmanuallysoftwareuser,termtypicallyrefersautomatedprocessesimplemented bot  webcrawler.formcopyingspecificdatagatheredcopiedweb,typicallycentrallocal database spreadsheet,later retrieval  analysis.
